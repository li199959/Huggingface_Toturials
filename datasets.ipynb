# %% [markdown]
# <a href="https://colab.research.google.com/github/li199959/Huggingface_Toturials/blob/main/datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
# !pip install datasets

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_dataset

# %%
dataset = load_dataset("csv", data_files="./dataset.csv", split="train")
# dataset = dataset.filter(lambda x: x["review"] is not None)
dataset
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-c940e6a55e9e7491/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
# Dataset({
#     features: ['text\tlabel'],
#     num_rows: 549
# })

# %%
datasets = dataset.train_test_split(test_size=0.1)
datasets

# %%
import torch
tokenizer = AutoTokenizer.from_pretrained("hfl/rbt3")

# %%
# 加载本地的 CSV 文件
dataset = load_dataset('csv', data_files='dataset.csv', delimiter='\t')

# 查看数据集信息
print(dataset)
# Out:
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/csv/default-deb0b529113fac36/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/1 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 549
#     })
# })

# %%
dataset[0:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-07b6f6f5c8de> in <cell line: 1>()
# ----> 1 dataset[0:10]
#
# /usr/local/lib/python3.10/dist-packages/datasets/dataset_dict.py in __getitem__(self, k)
#      61             ]
#      62             suggested_split = available_suggested_splits[0] if available_suggested_splits else list(self)[0]
# ---> 63             raise KeyError(
#      64                 f"Invalid key: {k}. Please first select a split. For example: "
#      65                 f"`my_dataset_dictionary['{suggested_split}'][{k}]`. "
#
# KeyError: "Invalid key: slice(0, 10, None). Please first select a split. For example: `my_dataset_dictionary['train'][slice(0, 10, None)]`. Available splits: ['train']"

# %%
def process_function(examples):
    tokenized_examples = tokenizer(examples["text"], max_length=128, truncation=True)
    tokenized_examples["labels"] = examples["label"]
    return tokenized_examples

tokenized_datasets = datasets.map(process_function, batched=True, remove_columns=datasets["train"].column_names)
tokenized_datasets
# Out:
# Map:   0%|          | 0/494 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-53b150812344> in <cell line: 6>()
#       4     return tokenized_examples
#       5
# ----> 6 tokenized_datasets = datasets.map(process_function, batched=True, remove_columns=datasets["train"].column_names)
#       7 tokenized_datasets
#
# /usr/local/lib/python3.10/dist-packages/datasets/dataset_dict.py in map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     849             cache_file_names = {k: None for k in self}
#     850         return DatasetDict(
# --> 851             {
#     852                 k: dataset.map(
#     853                     function=function,
# ...

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

# 加载本地的 CSV 文件
dataset = load_dataset('csv', data_files='dataset.csv', delimiter='\t')

# 获取训练集
train_dataset = dataset['train']

# 初始化 tokenizer
# tokenizer = AutoTokenizer.from_pretrained('tokenizer_name')

# 对文本进行标记化
tokenized_examples = tokenizer(train_dataset['text'], max_length=128, truncation=True)
# Out:
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/csv/default-deb0b529113fac36/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
tokenized_examples
# Out:
# {'input_ids': [[101, 8485, 8207, 2868, 2800, 680, 6981, 5390, 679, 671, 5636, 1440, 6356, 102], [101, 2207, 1277, 7028, 6981, 5390, 1927, 6571, 1440, 6356, 102], [101, 10640, 3171, 7216, 1440, 6356, 102], [101, 1045, 3563, 1779, 679, 1377, 4500, 102], [101, 1169, 2466, 7313, 6858, 928, 2460, 2382, 1440, 6356, 102], [101, 2198, 7574, 1296, 1039, 2207, 1277, 2456, 4989, 1927, 6571, 102], [101, 6566, 6770, 4223, 692, 3171, 1440, 6356, 102], [101, 2207, 1277, 3563, 2877, 6566, 6770, 1423, 1220, 1440, 6356, 102], [101, 3313, 6981, 5390, 3198, 7164, 1346, 5440, 3975, 1440, 6356, 102], [101, 2198, 7574, 1296, 1039, 1045, 7216, 6662, 1398, 3635, 4772, 3837, 696, 1927, 102], [101, 8638, 8207, 3352, 1305, 3946, 2428, 2460, 2382, 102], [101, 2198, 7574, 1296, 1039, 680, 2141, 7354, 6226, 1153, 679, 1276, 6981, 1440, 6356, 102], [101, 8638, 8207, 510, 12410, 1045, 3563, 1779, 3119, 1355, 2460, 2382, 1440, 6356, 102], [101, 3187, 1377, 4500, 10640, 7216, 6662, 102], [101, 2198, 7574, 1296, 1039, 
# ...

# %%
num_samples = len(tokenized_examples)

# %%
num_samples
# Out:
# 3
